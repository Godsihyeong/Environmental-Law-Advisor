# %%
import pandas as pd

data = pd.DataFrame(columns=['instruction', 'output'])

# %%
instruction = ['하수도법 시행규칙이 무엇인가요?',
               '유역 하수도 정비 계획의 정의는 무엇인가요?',
               '하수도 정비 중점 관리가 필요한 지역을 알려줘.',
               '하수도 정비 지역을 변경할 때 장관의 역할은 뭐야.',
               '하수도 정비 대책 수립 시에 필요한 내용은?',
               '하수관로 유지에 대한 조치를 알려줘.',
               '방류수 수질 기준에 대한 내용으로 뭐가 있을까.',
               '공공 하수도의 설치 및 관리에 대한 내용은 몇조 몇항이야.',
               '하수 저류 시설의 종류에 대해 말해줘.',
               '하수 저류 시설에 배치에 대한 세부 사항으로는 뭐가 있어?']
output = ['하수도법 시행규칙은 「하수도법」 및 같은 법 시행령에서 위임된 사항과 그 시행에 필요한 사항을 규정함을 목적으로 한다.',
          '유역환경청장 또는 지방환경청장(이하 “지방환경관서의 장”이라 한다)이 「하수도법」(이하 “법”이라 한다) 제4조의2제1항에 따라 유역하수도정비계획을 수립하여야 하는 권역은 한강, 낙동강, 금강, 영산강, 섬진강 권역으로 하되, 권역별 세부 단위유역은 환경부장관이 정하여 고시한다.',
          '하수의 범람으로 인하여 인명ㆍ재산 등의 피해가 반복적으로 발생하거나 발생할 우려가 있는 지역, 침수 피해가 발생하거나 발생할 우려가 있는 지역, 하수의 범람으로 인하여 취수원 또는 공공수역의 수질이 악화되었거나 악화될 우려가 있는 지역이다',
          '환경부장관은 중점관리지역을 지정ㆍ변경ㆍ해제하거나, 법 제4조의3제3항에 따라 특별시장ㆍ광역시장ㆍ시장 또는 군수(광역시의 군수는 제외한다)가 수립한 하수도정비대책에 대한 검토를 하기 위하여 필요하다고 인정하는 경우에는 미리 국립환경과학원장이나 「한국환경공단법」에 따른 한국환경공단의 의견을 들을 수 있다.',
          '하수도정비의 목표 및 이행 기간, 하수도 확충 및 유지ㆍ관리 계획, 강우 및 침수 피해 현황, 하수도정비 현황 및 문제점, 연차별 투자계획 및 재원조달 방안이 필요하다',
          '공공하수도관리청은 매년 12월 말까지 해당 연도의 하수관로 유지관리 실적과 다음 연도의 하수관로 유지관리계획을 지방환경관서의 장에게 제출해야 한다.',
          '공공하수처리시설ㆍ간이공공하수처리시설의 방류수수질기준은 별표 1과 같고, 분뇨처리시설의 방류수수질기준은 별표 2와 같다. 다만, 공공하수처리시설로 유입하여 처리하는 분뇨처리시설은 분뇨처리시설의 방류수수질기준을 적용하지 아니한다.',
          '제5조의2(공공하수도 설치인가의 경미한 변경)을 참고하면 됩니다.',
          '침수예방을 위한 시설, 수질오염 저감 시설, 하수의 재이용을 위한 시설로 총 3가지가 존재합니다.',
          '강우 시 침수피해를 예방할 수 있는 저지대나 하수관로 용량이 부족한 곳 등에 적정하게 배치하고, 오염된 하수를 효과적으로 수집하여 처리할 수 있는 곳에 배치하며, 유지ㆍ관리가 용이하고 경제성이 인정되는 곳에 배치해야 한다.']

# %%
data['instruction'] = instruction
data['output'] = output

# %%
data
# Out:
#                         instruction  \
# 0                 하수도법 시행규칙이 무엇인가요?
# 1          유역 하수도 정비 계획의 정의는 무엇인가요?
# 2        하수도 정비 중점 관리가 필요한 지역을 알려줘.
# 3      하수도 정비 지역을 변경할 때 장관의 역할은 뭐야.
# 4          하수도 정비 대책 수립 시에 필요한 내용은?
# 5              하수관로 유지에 대한 조치를 알려줘.
# 6        방류수 수질 기준에 대한 내용으로 뭐가 있을까.
# 7  공공 하수도의 설치 및 관리에 대한 내용은 몇조 몇항이야.
# 8             하수 저류 시설의 종류에 대해 말해줘.
# 9  하수 저류 시설에 배치에 대한 세부 사항으로는 뭐가 있어?
#
#                                               output
# 0  하수도법 시행규칙은 「하수도법」 및 같은 법 시행령에서 위임된 사항과 그 시행에 필...
# 1  유역환경청장 또는 지방환경청장(이하 “지방환경관서의 장”이라 한다)이 「하수도법」(...
# 2  하수의 범람으로 인하여 인명ㆍ재산 등의 피해가 반복적으로 발생하거나 발생할 우려가 ...
# 3  환경부장관은 중점관리지역을 지정ㆍ변경ㆍ해제하거나, 법 제4조의3제3항에 따라 특별시...
# 4  하수도정비의 목표 및 이행 기간, 하수도 확충 및 유지ㆍ관리 계획, 강우 및 침수 ...
# 5  공공하수도관리청은 매년 12월 말까지 해당 연도의 하수관로 유지관리 실적과 다음 연...
# 6  공공하수처리시설ㆍ간이공공하수처리시설의 방류수수질기준은 별표 1과 같고, 분뇨처리시설...
# 7               제5조의2(공공하수도 설치인가의 경미한 변경)을 참고하면 됩니다.
# 8  침수예방을 위한 시설, 수질오염 저감 시설, 하수의 재이용을 위한 시설로 총 3가지...
# ...

# %%
data.to_csv('./law.csv', index=False)
